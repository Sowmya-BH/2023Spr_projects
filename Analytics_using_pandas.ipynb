# %% [markdown]
# # Data Exploration using Pandas

# %% [markdown]
# #### The Panama Papers are 11.5 million leaked documents that detail financial and attorney–client information for more than 214,488 offshore entities. The documents, some dating back to the 1970s, were created by, and taken from, Panamanian law firm and corporate service provider Mossack Fonseca, and were leaked in 2015 by an anonymous source.

# %%
# load libraries
import pandas as pd
import numpy as np

import networkx as nx

import matplotlib.pyplot as plt
import seaborn as sns # this isn't actually required, but it makes our plots look nice
import ipywidgets

#%matplotlib inline

import random

# %%
# Loading the data into pandas for easy processing
Address = pd.read_csv("address.csv", low_memory=False)
Entities = pd.read_csv("Entities.csv", low_memory=False)
Intermediaries = pd.read_csv("Intermediaries.csv", low_memory=False)
Officers = pd.read_csv("Officers.csv", low_memory=False)
Edges = pd.read_csv("Edges.csv", low_memory=False)

# %% [markdown]
# ## Data Cleaning

# %%
df = pd.DataFrame(Officers['name'].value_counts().reset_index())
df.columns = ['name','count']
df.head(20)
# Out:
#                                   name  count
# 0                           The Bearer  72098
# 1                          EL PORTADOR   9325
# 2                          THE  BEARER    114
# 3   CHARITABLE AND GOODWILL FOUNDATION     92
# 4      NORTH ATLANTIC SERVICES LIMITED     91
# 5                       FORMIA LIMITED     77
# 6                MAYO NOMINEES LIMITED     76
# 7                  FIRST COURT LIMITED     76
# 8             MAYO SECRETARIES LIMITED     71
# 9            RICHMOND NOMINEES LIMITED     66
# 10                         GAIRNS LTD.     58
# 11                SECOND COURT LIMITED     56
# 12          CAVERSHAM NOMINEES LIMITED     56
# 13              BROCK NOMINEES LIMITED     53
# 14              MOHUL NOMINEES LIMITED     53
# 15                      KASTEL LIMITED     53
# 16              TENBY NOMINEES LIMITED     53
# 17       CAVERSHAM SECRETARIES LIMITED     52
# 18               LIVINGSTON GROUP S.A.     51
# 19            MINERVA NOMINEES LIMITED     50

# %%
Officers['name'] = Officers['name'].replace('THE BEARER', 'The Bearer')

# %%
Officers['name'] = Officers['name'].replace(['TO THE BEARER'], 'The Bearer')

# %%
Officers['name'] = Officers['name'].replace(['THE BEARER', 'BEARER','Bearer','THE BEARER','the bearer','The Bearer'], 'The Bearer')

# %%
Officers.head(20)
# Out:
#     Unnamed: 0   node_id                               name country_codes  \
# 0            0  12000001                         KIM SOO IN           KOR
# 1            1  12000002                          Tian Yuan           CHN
# 2            2  12000003               GREGORY JOHN SOLOMON           AUS
# 3            3  12000004                     MATSUDA MASUMI           JPN
# 4            4  12000005                        HO THUY NGA           VNM
# 5            5  12000006                     RACHMAT ARIFIN           AUS
# 6            6  12000007                        TAN SUN-HUA           PHL
# 7            7  12000008      Ou Yang Yet-Sing and Chang Ko           TWN
# 8            8  12000009  Wu Chi-Ping and Wu Chou Tsan-Ting           TWN
# 9            9  12000010                      ZHONG LI MING           CHN
# 10          10  12000011                           LIN PING           CHN
# 11          11  12000012                 BOSHEN LTD./135-77           NaN
# 12          12  12000013                 BOSHEN LTD./133-58           NaN
# 13          13  12000014                 BOSHEN LTD./132-50           NaN
# 14          14  12000015                        BOSHEN LTD.           NaN
# 15          15  12000016               ALGONQUIN TRUST LTD.           NaN
# 16          16  12000017             ALGONQUIN TRUST PANAMA           NaN
# 17          17  12000018              MIRABAUD & CIE/111-40           NaN
# 18          18  12000019                 BOSHEN LTD./137-93           NaN
# 19          19  12000020                 BOSHEN LTD./136-83           NaN
#
#       countries       sourceID  \
# 0   South Korea  Panama Papers
# 1         China  Panama Papers
# 2     Australia  Panama Papers
# 3         Japan  Panama Papers
# 4      Viet Nam  Panama Papers
# 5     Australia  Panama Papers
# 6   Philippines  Panama Papers
# 7        Taiwan  Panama Papers
# 8        Taiwan  Panama Papers
# 9         China  Panama Papers
# 10        China  Panama Papers
# 11          NaN  Panama Papers
# 12          NaN  Panama Papers
# 13          NaN  Panama Papers
# 14          NaN  Panama Papers
# 15          NaN  Panama Papers
# 16          NaN  Panama Papers
# 17          NaN  Panama Papers
# 18          NaN  Panama Papers
# 19          NaN  Panama Papers
#
#                                        valid_until note node_type
# 0   The Panama Papers data is current through 2015  NaN  Officers
# 1   The Panama Papers data is current through 2015  NaN  Officers
# 2   The Panama Papers data is current through 2015  NaN  Officers
# 3   The Panama Papers data is current through 2015  NaN  Officers
# 4   The Panama Papers data is current through 2015  NaN  Officers
# 5   The Panama Papers data is current through 2015  NaN  Officers
# 6   The Panama Papers data is current through 2015  NaN  Officers
# 7   The Panama Papers data is current through 2015  NaN  Officers
# 8   The Panama Papers data is current through 2015  NaN  Officers
# 9   The Panama Papers data is current through 2015  NaN  Officers
# 10  The Panama Papers data is current through 2015  NaN  Officers
# 11  The Panama Papers data is current through 2015  NaN  Officers
# 12  The Panama Papers data is current through 2015  NaN  Officers
# 13  The Panama Papers data is current through 2015  NaN  Officers
# 14  The Panama Papers data is current through 2015  NaN  Officers
# 15  The Panama Papers data is current through 2015  NaN  Officers
# 16  The Panama Papers data is current through 2015  NaN  Officers
# 17  The Panama Papers data is current through 2015  NaN  Officers
# 18  The Panama Papers data is current through 2015  NaN  Officers
# 19  The Panama Papers data is current through 2015  NaN  Officers

# %%
(Officers['name'].unique())
# Out:
# array(['KIM SOO IN', 'Tian Yuan', 'GREGORY JOHN SOLOMON', ...,
#        'Arkady Rotenberg', 'Boris Rotenberg', 'Jean-Claude N’Da Ametchi'],
#       dtype=object)

# %% [markdown]
# ### Countries with entites who opened most offshore offices

# %%
Entities
# Out:
#         Unnamed: 0   node_id                                         name  \
# 0                0  10000001     TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 1                1  10000002  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# 2                2  10000003                           HOTFOCUS CO., LTD.
# 3                3  10000004              SKY-BLUE GIFTS & TOYS CO., LTD.
# 4                4  10000005         FORTUNEMAKER INVESTMENTS CORPORATION
# ...            ...       ...                                          ...
# 213629      213629  10214482                MILLION TECH DEVELOPMENT LTD.
# 213630      213630  10214483          FAITH CONNECTION INTERNATIONAL LTD.
# 213631      213631  10214484             LARK OVERSEAS INVESTMENT LIMITED
# 213632      213632  10214486                         ASTRA SKIES  LIMITED
# 213633      213633  10214487                  Kilimanjaro Capital Limited
#
#        jurisdiction jurisdiction_description country_codes  \
# 0               SAM                    Samoa           HKG
# 1               SAM                    Samoa           HKG
# 2               SAM                    Samoa           HKG
# 3               SAM                    Samoa           HKG
# 4               SAM                    Samoa           HKG
# ...             ...                      ...           ...
# 213629          BVI   British Virgin Islands           HKG
# 213630          BVI   British Virgin Islands           HKG
# 213631          BVI   British Virgin Islands           HKG
# 213632          BVI   British Virgin Islands           ARE
# 213633          BVI   British Virgin Islands           ARE
#
#                    countries incorporation_date inactivation_date  \
# 0                  Hong Kong        23-MAR-2006       18-FEB-2013
# 1                  Hong Kong        27-MAR-2006       27-FEB-2014
# 2                  Hong Kong        10-JAN-2006       15-FEB-2012
# 3                  Hong Kong        06-JAN-2006       16-FEB-2009
# 4                  Hong Kong        19-APR-2006       15-MAY-2009
# ...                      ...                ...               ...
# 213629             Hong Kong        05-JAN-2010       01-NOV-2011
# 213630             Hong Kong        05-JAN-2010       01-NOV-2011
# 213631             Hong Kong        04-JAN-2010       01-NOV-2013
# 213632  United Arab Emirates        15-DEC-2009       09-DEC-2011
# 213633  United Arab Emirates        31-DEC-2009       06-NOV-2012
#
#        struck_off_date  closed_date  ibcRUC         status  company_type  \
# 0          15-FEB-2013          NaN   25221      Defaulted           NaN
# 1          15-FEB-2014          NaN   25249      Defaulted           NaN
# 2          15-FEB-2012          NaN   24138      Defaulted           NaN
# 3          15-FEB-2009          NaN   24012      Defaulted           NaN
# 4          15-FEB-2008          NaN  R25638  Changed agent           NaN
# ...                ...          ...     ...            ...           ...
# 213629     31-OCT-2011          NaN     NaN      Defaulted           NaN
# 213630     31-OCT-2011          NaN     NaN      Defaulted           NaN
# 213631     31-OCT-2013          NaN     NaN      Defaulted           NaN
# 213632     30-APR-2012          NaN     NaN  Changed agent           NaN
# 213633     30-APR-2013          NaN     NaN  Changed agent           NaN
#
#        service_provider       sourceID  \
# 0       Mossack Fonseca  Panama Papers
# 1       Mossack Fonseca  Panama Papers
# 2       Mossack Fonseca  Panama Papers
# 3       Mossack Fonseca  Panama Papers
# 4       Mossack Fonseca  Panama Papers
# ...                 ...            ...
# 213629  Mossack Fonseca  Panama Papers
# 213630  Mossack Fonseca  Panama Papers
# 213631  Mossack Fonseca  Panama Papers
# 213632  Mossack Fonseca  Panama Papers
# 213633  Mossack Fonseca  Panama Papers
#
#                                            valid_until note node_type
# 0       The Panama Papers data is current through 2015  NaN    Entity
# 1       The Panama Papers data is current through 2015  NaN    Entity
# 2       The Panama Papers data is current through 2015  NaN    Entity
# 3       The Panama Papers data is current through 2015  NaN    Entity
# 4       The Panama Papers data is current through 2015  NaN    Entity
# ...                                                ...  ...       ...
# 213629  The Panama Papers data is current through 2015  NaN    Entity
# 213630  The Panama Papers data is current through 2015  NaN    Entity
# 213631  The Panama Papers data is current through 2015  NaN    Entity
# 213632  The Panama Papers data is current through 2015  NaN    Entity
# 213633  The Panama Papers data is current through 2015  NaN    Entity
#
# [213634 rows x 19 columns]

# %%
Entities['service_provider'].value_counts()
# Out:
# Mossack Fonseca    213634
# Name: service_provider, dtype: int64

# %% [markdown]
# **The service provider for all the entities is Mossack Fonseca.However the role of the firm in the establishment of these entities from the dataframe alone is unclear.**

# %%
x_ent = pd.DataFrame(Entities['countries'].value_counts()).reset_index()
x_ent.columns = ['countries','count']
x_ent
# Out:
#           countries  count
# 0         Hong Kong  37911
# 1       Switzerland  37911
# 2            Panama  15811
# 3            Jersey  14331
# 4        Luxembourg  10840
# ..              ...    ...
# 154         Liberia      1
# 155           Yemen      1
# 156         Georgia      1
# 157  American Samoa      1
# 158        Slovakia      1
#
# [159 rows x 2 columns]

# %%
plt.style.use("fivethirtyeight")
@ipywidgets.interact(count=[1000,500,100,1],color=['olive','maroon','green','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
def plot_bars(count,color):
    #figure(figsize=(15,7))
    #figure(figsize=(15,7))
    filtered_df = x_ent[x_ent['count'] > count]
    filtered_df.plot(kind='bar', x='countries', y='count',color=color,figsize=[20,5])
    plt.title("Countries with entites who open offshore accounts",fontsize=15,fontweight='bold')
    plt.ylabel("Number of offices",fontsize=15)

    #plt.figure()
    plt.show()
#     plt.bar(x = np.array(x[x['count']>1000].countries), height = np.array(x[x['count']>1000].count), color =color,width = 0.8)
    #plt.show()
# Out:
# interactive(children=(Dropdown(description='count', options=(1000, 500, 100, 1), value=1000), Dropdown(descrip…

# %% [markdown]
# **Most of the corporate clients of Mossack Fonseca were from Hong Kong, Switzerland, the United Kingdom, Luxembourg, Panama, and Cyprus.**

# %%
Entities
# Out:
#         Unnamed: 0   node_id                                         name  \
# 0                0  10000001     TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 1                1  10000002  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# 2                2  10000003                           HOTFOCUS CO., LTD.
# 3                3  10000004              SKY-BLUE GIFTS & TOYS CO., LTD.
# 4                4  10000005         FORTUNEMAKER INVESTMENTS CORPORATION
# ...            ...       ...                                          ...
# 213629      213629  10214482                MILLION TECH DEVELOPMENT LTD.
# 213630      213630  10214483          FAITH CONNECTION INTERNATIONAL LTD.
# 213631      213631  10214484             LARK OVERSEAS INVESTMENT LIMITED
# 213632      213632  10214486                         ASTRA SKIES  LIMITED
# 213633      213633  10214487                  Kilimanjaro Capital Limited
#
#        jurisdiction jurisdiction_description country_codes  \
# 0               SAM                    Samoa           HKG
# 1               SAM                    Samoa           HKG
# 2               SAM                    Samoa           HKG
# 3               SAM                    Samoa           HKG
# 4               SAM                    Samoa           HKG
# ...             ...                      ...           ...
# 213629          BVI   British Virgin Islands           HKG
# 213630          BVI   British Virgin Islands           HKG
# 213631          BVI   British Virgin Islands           HKG
# 213632          BVI   British Virgin Islands           ARE
# 213633          BVI   British Virgin Islands           ARE
#
#                    countries incorporation_date inactivation_date  \
# 0                  Hong Kong         2006-03-23       18-FEB-2013
# 1                  Hong Kong         2006-03-27       27-FEB-2014
# 2                  Hong Kong         2006-01-10       15-FEB-2012
# 3                  Hong Kong         2006-01-06       16-FEB-2009
# 4                  Hong Kong         2006-04-19       15-MAY-2009
# ...                      ...                ...               ...
# 213629             Hong Kong         2010-01-05       01-NOV-2011
# 213630             Hong Kong         2010-01-05       01-NOV-2011
# 213631             Hong Kong         2010-01-04       01-NOV-2013
# 213632  United Arab Emirates         2009-12-15       09-DEC-2011
# 213633  United Arab Emirates         2009-12-31       06-NOV-2012
#
#        struck_off_date  closed_date  ibcRUC         status  company_type  \
# 0          15-FEB-2013          NaN   25221      Defaulted           NaN
# 1          15-FEB-2014          NaN   25249      Defaulted           NaN
# 2          15-FEB-2012          NaN   24138      Defaulted           NaN
# 3          15-FEB-2009          NaN   24012      Defaulted           NaN
# 4          15-FEB-2008          NaN  R25638  Changed agent           NaN
# ...                ...          ...     ...            ...           ...
# 213629     31-OCT-2011          NaN     NaN      Defaulted           NaN
# 213630     31-OCT-2011          NaN     NaN      Defaulted           NaN
# 213631     31-OCT-2013          NaN     NaN      Defaulted           NaN
# 213632     30-APR-2012          NaN     NaN  Changed agent           NaN
# 213633     30-APR-2013          NaN     NaN  Changed agent           NaN
#
#        service_provider       sourceID  \
# 0       Mossack Fonseca  Panama Papers
# 1       Mossack Fonseca  Panama Papers
# 2       Mossack Fonseca  Panama Papers
# 3       Mossack Fonseca  Panama Papers
# 4       Mossack Fonseca  Panama Papers
# ...                 ...            ...
# 213629  Mossack Fonseca  Panama Papers
# 213630  Mossack Fonseca  Panama Papers
# 213631  Mossack Fonseca  Panama Papers
# 213632  Mossack Fonseca  Panama Papers
# 213633  Mossack Fonseca  Panama Papers
#
#                                            valid_until note node_type
# 0       The Panama Papers data is current through 2015  NaN    Entity
# 1       The Panama Papers data is current through 2015  NaN    Entity
# 2       The Panama Papers data is current through 2015  NaN    Entity
# 3       The Panama Papers data is current through 2015  NaN    Entity
# 4       The Panama Papers data is current through 2015  NaN    Entity
# ...                                                ...  ...       ...
# 213629  The Panama Papers data is current through 2015  NaN    Entity
# 213630  The Panama Papers data is current through 2015  NaN    Entity
# 213631  The Panama Papers data is current through 2015  NaN    Entity
# 213632  The Panama Papers data is current through 2015  NaN    Entity
# 213633  The Panama Papers data is current through 2015  NaN    Entity
#
# [213634 rows x 19 columns]

# %%
# Convert to datetime
Entities["incorporation_date"] = pd.to_datetime(Entities["incorporation_date"],format='%d-%b-%Y',errors='coerce')

# %%
Entities["incorporation_year"]=Entities["incorporation_date"].dt.year

# %%
#Effective Date
Entities["inactivation_date"] = pd.to_datetime(Entities["inactivation_date"],
                                           format='%d-%b-%Y',errors='coerce')

# %%
Entities["inactivation_year"] = Entities["inactivation_date"].dt.year

# %%
x_year = pd.DataFrame((Entities['incorporation_year'].value_counts()).reset_index())
x_year.columns = ['incorporation_year','count']
x_year
# Out:
#     incorporation_year  count
# 0               2005.0  13246
# 1               2007.0  12814
# 2               2006.0  12355
# 3               2004.0  11014
# 4               2008.0  10836
# ..                 ...    ...
# 59              1936.0      1
# 60              1961.0      1
# 61              1945.0      1
# 62              1951.0      1
# 63              1954.0      1
#
# [64 rows x 2 columns]

# %%
plt.style.use("fivethirtyeight")
@ipywidgets.interact(count=[5000,1000,500,100,1],color=['olive','maroon','green','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
def plot_bars(count,color):
    filtered_df_ent = x_year[x_year['count'] > count]
    filtered_df_ent.plot( x='incorporation_year', y='count',color=color,figsize=[20,5])   
    plt.title("Yearly Incorporation counts",fontsize=15,fontweight='bold')
    plt.ylabel("Number of offshore offices opened",fontsize=15)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='count', options=(5000, 1000, 500, 100, 1), value=5000), Dropdown(d…

# %% [markdown]
# **Number of offshore entities established increased after 1990.**

# %%
x_year_inactivation = pd.DataFrame((Entities['inactivation_year'].value_counts()).reset_index())
x_year_inactivation.columns = ['inactivation_year','count']
x_year_inactivation
# Out:
#     inactivation_year  count
# 0              2010.0   9973
# 1              2009.0   9072
# 2              2014.0   9017
# 3              2013.0   8913
# 4              2015.0   8862
# 5              2011.0   8163
# 6              2008.0   7507
# 7              2006.0   7440
# 8              2012.0   7024
# 9              2007.0   6693
# 10             2002.0   6621
# 11             2005.0   6524
# 12             2001.0   6514
# 13             2004.0   6088
# 14             2003.0   5945
# 15             2000.0   5132
# 16             1999.0   4843
# 17             1998.0   4165
# 18             1997.0   3543
# 19             1996.0   3348
# 20             1995.0   2001
# 21             1994.0   1855
# 22             1993.0   1415
# 23             1991.0   1166
# 24             1992.0    897
# 25             1990.0    784
# 26             1989.0    581
# 27             1988.0    225
# 28             1987.0    170
# 29             1984.0     79
# 30             1986.0     60
# 31             1985.0     55
# 32             1983.0     33
# 33             1982.0     29
# 34             1981.0      8
# 35             1980.0      6
# 36             1979.0      5
# 37             1967.0      1
# 38             1968.0      1
# 39             1978.0      1
# 40             1930.0      1

# %%
plt.style.use("fivethirtyeight")
@ipywidgets.interact(count=[5000,1000,500,100,1],color=['olive','maroon','green','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
def plot_bars(count,color):
    filtered_df_ent = x_year_inactivation[x_year_inactivation['count'] > count]
    filtered_df_ent.plot( x='inactivation_year', y='count',color=color,figsize=[20,5])   
    plt.title("Yearly Incorporation counts",fontsize=15,fontweight='bold')
    plt.ylabel("Number of offshore offices opened",fontsize=15)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='count', options=(5000, 1000, 500, 100, 1), value=5000), Dropdown(d…

# %% [markdown]
# ## Tax Havens

# %%
Address
# Out:
#        Unnamed: 0   node_id  name  \
# 0               0  14000001   NaN
# 1               1  14000002   NaN
# 2               2  14000003   NaN
# 3               3  14000004   NaN
# 4               4  14000005   NaN
# ...           ...       ...   ...
# 93449       93449  14109121   NaN
# 93450       93450  14109122   NaN
# 93451       93451  14109129   NaN
# 93452       93452  14109130   NaN
# 93453       93453  14109133   NaN
#
#                                                  address country_codes  \
# 0           -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920           SGP
# 1                "Almaly Village" v.5, Almaty Kazakhstan           KAZ
# 2      "Cantonia" South Road St Georges Hill Weybridg...           GBR
# 3      "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...           GGY
# 4      "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...           KEN
# ...                                                  ...           ...
# 93449  ZOLDOR HOLDINGS CORP. PANAMA REPUBLIC OF PANAM...           PAN
# 93450  ZONE RESOURCES LIMITED 3705 GLOUCESTER TOWER; ...           HKG
# 93451  ZURELDA TRADING S.A. AKARA BLDG.; 24 DE CASTRO...           VGB
# 93452  ZURICH TRADING LIMITED AKARA BLDG.; 24 DE CAST...           VGB
# 93453  ZYB ENERGY CO.; LTD. (BC NO.: 1440969)   ACCOU...           CHN
#
#                     countries       sourceID  \
# 0                   Singapore  Panama Papers
# 1                  Kazakhstan  Panama Papers
# 2              United Kingdom  Panama Papers
# 3                    Guernsey  Panama Papers
# 4                       Kenya  Panama Papers
# ...                       ...            ...
# 93449                  Panama  Panama Papers
# 93450               Hong Kong  Panama Papers
# 93451  British Virgin Islands  Panama Papers
# 93452  British Virgin Islands  Panama Papers
# 93453                   China  Panama Papers
#
#                                            valid_until  note node_type
# 0      The Panama Papers  data is current through 2015   NaN   address
# 1      The Panama Papers  data is current through 2015   NaN   address
# 2      The Panama Papers  data is current through 2015   NaN   address
# 3      The Panama Papers  data is current through 2015   NaN   address
# 4      The Panama Papers  data is current through 2015   NaN   address
# ...                                                ...   ...       ...
# 93449  The Panama Papers  data is current through 2015   NaN   address
# 93450  The Panama Papers  data is current through 2015   NaN   address
# 93451  The Panama Papers  data is current through 2015   NaN   address
# 93452  The Panama Papers  data is current through 2015   NaN   address
# 93453  The Panama Papers  data is current through 2015   NaN   address
#
# [93454 rows x 10 columns]

# %%
x_Address = pd.DataFrame((Address['countries'].value_counts()).reset_index())
x_Address.columns = ['countries','count']
x_Address
# Out:
#                       countries  count
# 0                         China  20267
# 1                     Hong Kong   9147
# 2                United Kingdom   3996
# 3        British Virgin Islands   3467
# 4                        Russia   3346
# ..                          ...    ...
# 197               Guinea-Bissau      1
# 198  Saint Martin (French part)      1
# 199                  San Marino      1
# 200                     Grenada      1
# 201                  Kyrgyzstan      1
#
# [202 rows x 2 columns]

# %%
plt.style.use("fivethirtyeight")
@ipywidgets.interact(count=[5000,1000,500,100,1],color=['olive','maroon','green','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
def plot_bars(count,color):
    filtered_df_ent = x_Address[x_Address['count'] > count]
    filtered_df_ent.plot(kind='bar', x='countries', y='count',color=color,figsize=[20,5])   
    plt.title("Countries by intermediaries",fontsize=15,fontweight='bold')
    plt.ylabel("Number of officers",fontsize=15)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='count', options=(5000, 1000, 500, 100, 1), value=5000), Dropdown(d…

# %% [markdown]
# **Most popular tax havens among the clients of Mossack Fonseca.**

# %%
x_officers = pd.DataFrame((Officers['countries'].value_counts()).reset_index())
x_officers.columns = ['countries','count']
x_officers
# Out:
#                       countries  count
# 0                         China  24635
# 1                     Hong Kong  13362
# 2        British Virgin Islands  11231
# 3                        Jersey   6892
# 4                        Panama   5069
# ..                          ...    ...
# 196                       Niger      1
# 197  Saint Martin (French part)      1
# 198                Burkina Faso      1
# 199                  San Marino      1
# 200                  Kyrgyzstan      1
#
# [201 rows x 2 columns]

# %%
plt.style.use("fivethirtyeight")
@ipywidgets.interact(count=[5000,1000,500,100,1],color=['olive','maroon','green','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
def plot_bars(count,color):
    filtered_df_ent = x_officers[x_officers['count'] > count]
    filtered_df_ent.plot(kind='bar', x='countries', y='count',color=color,figsize=[20,5])   
    plt.title("Countries by officers",fontsize=15,fontweight='bold')
    plt.ylabel("Number of officers",fontsize=15)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='count', options=(5000, 1000, 500, 100, 1), value=5000), Dropdown(d…

# %%
x_intermediary = pd.DataFrame((Intermediaries['countries'].value_counts()).reset_index())
x_intermediary.columns = ['countries','count']
x_intermediary
# Out:
#                      countries  count
# 0                    Hong Kong   2202
# 1               United Kingdom   1367
# 2                  Switzerland   1218
# 3                United States    603
# 4                       Panama    552
# ..                         ...    ...
# 236                Puerto Rico      1
# 237   Mauritius;United Kingdom      1
# 238              Jersey;Cyprus      1
# 239  Panama;Dominican Republic      1
# 240    United Kingdom;Thailand      1
#
# [241 rows x 2 columns]

# %%
plt.style.use("fivethirtyeight")
@ipywidgets.interact(count=[1000,500,100,1],color=['olive','maroon','green','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
def plot_bars(count,color):
    filtered_df_ent = x_intermediary[x_intermediary['count'] > count]
    filtered_df_ent.plot(kind='bar', x='countries', y='count',color=color,figsize=[20,5])   
    plt.title("Countries by intermediaries",fontsize=15,fontweight='bold')
    plt.ylabel("Number of officers",fontsize=15)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='count', options=(1000, 500, 100, 1), value=1000), Dropdown(descrip…

# %%
# Popular

# %%
plt.style.use("fivethirtyeight")
@ipywidgets.interact(count=[5000,1000,500,100,1],color=['olive','maroon','green','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
def plot_bars(count,color):
    filtered_df_ent = x_officers[x_officers['count'] > count]
    filtered_df_ent.plot(kind='bar', x='countries', y='count',color=color,figsize=[20,5])   
    plt.title("Countries by officers",fontsize=15,fontweight='bold')
    plt.ylabel("Number of officers",fontsize=15)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='count', options=(5000, 1000, 500, 100, 1), value=5000), Dropdown(d…

# %%
Address
# Out:
#        Unnamed: 0   node_id  name  \
# 0               0  14000001   NaN
# 1               1  14000002   NaN
# 2               2  14000003   NaN
# 3               3  14000004   NaN
# 4               4  14000005   NaN
# ...           ...       ...   ...
# 93449       93449  14109121   NaN
# 93450       93450  14109122   NaN
# 93451       93451  14109129   NaN
# 93452       93452  14109130   NaN
# 93453       93453  14109133   NaN
#
#                                                  address country_codes  \
# 0           -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920           SGP
# 1                "Almaly Village" v.5, Almaty Kazakhstan           KAZ
# 2      "Cantonia" South Road St Georges Hill Weybridg...           GBR
# 3      "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...           GGY
# 4      "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...           KEN
# ...                                                  ...           ...
# 93449  ZOLDOR HOLDINGS CORP. PANAMA REPUBLIC OF PANAM...           PAN
# 93450  ZONE RESOURCES LIMITED 3705 GLOUCESTER TOWER; ...           HKG
# 93451  ZURELDA TRADING S.A. AKARA BLDG.; 24 DE CASTRO...           VGB
# 93452  ZURICH TRADING LIMITED AKARA BLDG.; 24 DE CAST...           VGB
# 93453  ZYB ENERGY CO.; LTD. (BC NO.: 1440969)   ACCOU...           CHN
#
#                     countries       sourceID  \
# 0                   Singapore  Panama Papers
# 1                  Kazakhstan  Panama Papers
# 2              United Kingdom  Panama Papers
# 3                    Guernsey  Panama Papers
# 4                       Kenya  Panama Papers
# ...                       ...            ...
# 93449                  Panama  Panama Papers
# 93450               Hong Kong  Panama Papers
# 93451  British Virgin Islands  Panama Papers
# 93452  British Virgin Islands  Panama Papers
# 93453                   China  Panama Papers
#
#                                            valid_until  note node_type
# 0      The Panama Papers  data is current through 2015   NaN   address
# 1      The Panama Papers  data is current through 2015   NaN   address
# 2      The Panama Papers  data is current through 2015   NaN   address
# 3      The Panama Papers  data is current through 2015   NaN   address
# 4      The Panama Papers  data is current through 2015   NaN   address
# ...                                                ...   ...       ...
# 93449  The Panama Papers  data is current through 2015   NaN   address
# 93450  The Panama Papers  data is current through 2015   NaN   address
# 93451  The Panama Papers  data is current through 2015   NaN   address
# 93452  The Panama Papers  data is current through 2015   NaN   address
# 93453  The Panama Papers  data is current through 2015   NaN   address
#
# [93454 rows x 10 columns]

# %%
x_Address = pd.DataFrame((Address['countries'].value_counts()).reset_index())
x_Address.columns = ['countries','count']
x_Address
# Out:
#                       countries  count
# 0                         China  20267
# 1                     Hong Kong   9147
# 2                United Kingdom   3996
# 3        British Virgin Islands   3467
# 4                        Russia   3346
# ..                          ...    ...
# 197               Guinea-Bissau      1
# 198  Saint Martin (French part)      1
# 199                  San Marino      1
# 200                     Grenada      1
# 201                  Kyrgyzstan      1
#
# [202 rows x 2 columns]

# %%
plt.style.use("fivethirtyeight")
@ipywidgets.interact(count=[5000,1000,500,100,1],color=['olive','maroon','green','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
def plot_bars(count,color):
    filtered_df_ent = x_Address[x_Address['count'] > count]
    filtered_df_ent.plot(kind='bar', x='countries', y='count',color=color,figsize=[20,5])   
    plt.title("Countries by intermediaries",fontsize=15,fontweight='bold')
    plt.ylabel("Number of officers",fontsize=15)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='count', options=(5000, 1000, 500, 100, 1), value=5000), Dropdown(d…

# %% [markdown]
# **Most popular tax havens among the clients of Mossack Fonseca.**
