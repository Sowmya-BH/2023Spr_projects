# %% [markdown]
# *The **Panama Papers** are 11.5 million leaked documents that detail financial and attorney–client information for more than 206,525 offshore entities. The documents, some dating back to the 1970s, were created by, and taken from, Panamanian law firm and corporate service provider Mossack Fonseca, and were leaked in 2015 by an anonymous source.*

# %%
# load libraries
import pandas as pd
import numpy as np

import networkx as nx

import matplotlib.pyplot as plt
import seaborn as sns # this isn't actually required, but it makes our plots look nice
import ipywidgets
#%matplotlib inline

import random

# %%
# Loading the data into pandas for easy processing
adds = pd.read_csv("panama_papers.nodes.address.csv", low_memory=False)
adds
# Out:
#         node_id  name                                            address  \
# 0      14000001   NaN       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1      14000002   NaN            "Almaly Village" v.5, Almaty Kazakhstan
# 2      14000003   NaN  "Cantonia" South Road St Georges Hill Weybridg...
# 3      14000004   NaN  "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...
# 4      14000005   NaN  "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...
# ...         ...   ...                                                ...
# 93449  14109121   NaN  ZOLDOR HOLDINGS CORP. PANAMA REPUBLIC OF PANAM...
# 93450  14109122   NaN  ZONE RESOURCES LIMITED 3705 GLOUCESTER TOWER; ...
# 93451  14109129   NaN  ZURELDA TRADING S.A. AKARA BLDG.; 24 DE CASTRO...
# 93452  14109130   NaN  ZURICH TRADING LIMITED AKARA BLDG.; 24 DE CAST...
# 93453  14109133   NaN  ZYB ENERGY CO.; LTD. (BC NO.: 1440969)   ACCOU...
#
#       country_codes               countries       sourceID  \
# ...

# %%
x = pd.DataFrame(adds['countries'].value_counts()).reset_index()
x.columns = ['countries','count']
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   countries  202 non-null    object
#  1   count      202 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 3.3+ KB

# %%
# temp_df = x[x['count']>1000]
# temp_df
print(np.array(x[x['count']>1000]['countries']))
# Out:
# ['China' 'Hong Kong' 'United Kingdom' 'British Virgin Islands' 'Russia'
#  'United States' 'Jersey' 'Switzerland' 'Panama' 'Taiwan' 'Singapore'
#  'United Arab Emirates' 'Guernsey' 'Cyprus' 'Brazil' 'South Africa'
#  'Malaysia' 'Isle of Man' 'Peru']

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
# @ipywidgets.interact(x=bf_numerical_features.columns,y=['state', 'season', 'classification', 'uv_index','latitude', 'longitude'],color_map = ['humidity','wind_bearing','wind_speed','temperature_mid'],marker_name=['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd'])
# def scatter_plot(x,y,color_map,marker_name):

# %%
# plt.style.use("fivethirtyeight")
# @ipywidgets.interact(count=[1000,500,100,1],color=['maroon','green','olive','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
# def plot_bars(count,color):
#     #figure(figsize=(15,7))
#     #figure(figsize=(15,7))
#     filtered_df = x[x['count'] > count]
#     filtered_df.plot(kind='bar', x='countries', y='count',color=color,figsize=[20,5])
#     plt.title("World's best tax havens",fontsize='bold',fontsize=5)
#     plt.ylabel("Number of offices",fontsize=20)


#     #plt.figure()
#     plt.show()
# #     plt.bar(x = np.array(x[x['count']>1000].countries), height = np.array(x[x['count']>1000].count), color =color,width = 0.8)
#     #plt.show()
# Out:
#   Input In [7]
#     plt.title("World's best tax havens",fontsize='bold',fontsize=5)
#                                                         ^
# SyntaxError: keyword argument repeated: fontsize

# %%
# # create a bar plot function
# def plot_bars(count):
#     filtered_df = x[x['count'] > count]
#     filtered_df.plot(kind='bar', x='countries', y='count')
#     plt.show()


# # create an interactive slider widget
# count_slider = widgets.IntSlider(value=1000, min=0, max=20267, step=500)

# # create a callback function for the slider widget
# def on_value_change(change):
#     plot_bars(change.new)

# # link the slider widget to the callback function
# count_slider.observe(on_value_change, names='value')

# # display the slider widget
# display(count_slider)

# %%
# # create a bar plot function
# def plot_bars(count):
#     filtered_df = x[x['count'] > count]
#     filtered_df.plot(kind='bar', x='countries', y='count')
#     plt.show()


# # create an interactive slider widget
# count_slider = widgets.IntSlider(value=1000, min=0, max=20267, step=500)

# # create a callback function for the slider widget
# def on_value_change(change):
#     plot_bars(change.new)

# # link the slider widget to the callback function
# count_slider.observe(on_value_change, names='value')

# # display the slider widget
# display(count_slider)
# Out:
# IntSlider(value=1000, max=20267, step=500)

# %%
#temp_df.values

# %%
### Exploratory Data Analysis

# %%
# with plt.style.context("fivethirtyeight"):
#     fig = plt.figure(figsize = (30, 5))
#     plt.bar(temp_df['countries'],temp_df['count'], color ='maroon',width = 0.8)
#     plt.xlabel("countries offices are located")
#     plt.ylabel("Number of offices")
#     plt.xticks(rotation=90,fontweight='bold',fontsize=10)
#     plt.title("World's best tax havens")
#     plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
#       1 with plt.style.context("fivethirtyeight"):
#       2     fig = plt.figure(figsize = (30, 5))
# ----> 3     plt.bar(temp_df['countries'],temp_df['count'], color ='maroon',width = 0.8)
#       4     plt.xlabel("countries offices are located")
#       5     plt.ylabel("Number of offices")
#
# NameError: name 'temp_df' is not defined

# %% [markdown]
# #### Gray-listed jurisdiction for its alleged failure to prevent money laundering and terrorism financing

# %%
# @ipywidgets.interact(count=[1000,500,100,1])
# def plot_bars(count):
#     plt.bar(x[x['count']>count].countries, x[x['count']>count].count, color ='maroon',width = 0.8)

#     #with plt.style.context("fivethirtyeight"):
#     #fig = plt.figure(figsize = (30, 5))
#     #plt.bar(temp_df['countries'],temp_df['count'], color ='green',width = 0.8)
#     plt.xlabel("countries offices are located")
#     plt.ylabel("Number of offices")
#     plt.xticks(rotation=90,fontweight='bold',fontsize=10)
#     plt.title("World's best tax havens")
#     plt.show()

# %% [markdown]
# **Offshore Leaks** is the name of a report disclosing details of 130,000 offshore accounts in April 2013. Some observers have called it the biggest hit against international tax fraud of all times, although it has been pointed out that normal businesses may use the offshore legislation to ease formalities in international trade. The report originated from the Washington D.C.-based investigative journalism nonprofit, the International Consortium of Investigative Journalists (ICIJ), who collaborated with reporters around the world to produce the series of investigative reports published in connection with ICIJ's The Global Muckraker. The investigation is based on a cache of 2.5 million secret records about the offshore assets of people from 170 countries and territories, obtained by ICIJ's director, Gerard Ryle

# %%
ents = pd.read_csv("panama_papers.nodes.entity.csv", low_memory=False)
ents
# Out:
#          node_id                                         name jurisdiction  \
# 0       10000001     TIANSHENG INDUSTRY AND TRADING CO., LTD.          SAM
# 1       10000002  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.          SAM
# 2       10000003                           HOTFOCUS CO., LTD.          SAM
# 3       10000004              SKY-BLUE GIFTS & TOYS CO., LTD.          SAM
# 4       10000005         FORTUNEMAKER INVESTMENTS CORPORATION          SAM
# ...          ...                                          ...          ...
# 213629  10214482                MILLION TECH DEVELOPMENT LTD.          BVI
# 213630  10214483          FAITH CONNECTION INTERNATIONAL LTD.          BVI
# 213631  10214484             LARK OVERSEAS INVESTMENT LIMITED          BVI
# 213632  10214486                         ASTRA SKIES  LIMITED          BVI
# 213633  10214487                  Kilimanjaro Capital Limited          BVI
#
# ...

# %%
ents['name'].value_counts()
# Out:
# BRITTEN TRADING LIMITED                5
# SUNMEAD MANAGEMENT LIMITED             5
# LATITUD 33 CORP.                       5
# KAMBER LIMITED                         5
# MEMBERS FACTORS LIMITED                4
#                                       ..
# MAN LEE INTERNATIONAL SERVICES LTD.    1
# BETRO HOLDING CORP.                    1
# NATVEST FINANCE CORP.                  1
# SHOUP MANAGEMENT INC.                  1
# Kilimanjaro Capital Limited            1
# Name: name, Length: 206525, dtype: int64

# %%
ents['service_provider'].value_counts()
# Out:
# Mossack Fonseca    213634
# Name: service_provider, dtype: int64

# %%
x_ent = pd.DataFrame(ents['countries'].value_counts()).reset_index()
x_ent.columns = ['countries','count']
x_ent
# Out:
#           countries  count
# 0         Hong Kong  37911
# 1       Switzerland  37911
# 2            Panama  15811
# 3            Jersey  14331
# 4        Luxembourg  10840
# ..              ...    ...
# 154         Liberia      1
# 155           Yemen      1
# 156         Georgia      1
# 157  American Samoa      1
# 158        Slovakia      1
#
# [159 rows x 2 columns]

# %%
temp_df_ent = x_ent[x_ent['count']>1000]
temp_df_ent
# Out:
#                  countries  count
# 0                Hong Kong  37911
# 1              Switzerland  37911
# 2                   Panama  15811
# 3                   Jersey  14331
# 4               Luxembourg  10840
# 5           United Kingdom   9619
# 6                 Guernsey   7327
# 7     United Arab Emirates   7269
# 8                  Bahamas   4984
# 9                  Uruguay   4906
# 10             Isle of Man   4892
# 11                  Russia   4197
# 12               Singapore   4081
# 13                  Cyprus   3613
# 14                   China   3213
# 15                  Monaco   3168
# 16           United States   3066
# 17                  Taiwan   2725
# 18           Liechtenstein   2066
# 19               Gibraltar   2039
# 20                Colombia   1854
# 21                 Ecuador   1852
# 22                   Samoa   1613
# 23                  Jordan   1553
# 24                  Brazil   1399
# 25                  Latvia   1380
# ...

# %%
with plt.style.context("fivethirtyeight"):
    fig = plt.figure(figsize = (30, 5))
    plt.bar(temp_df_ent['countries'],temp_df_ent['count'], color ='maroon',width = 0.8)
    plt.xlabel("countries entities are located")
    plt.ylabel("Number of offices")
    plt.xticks(rotation=90,fontweight='bold',fontsize=10)
    plt.title("Countries with entites who open offshore accounts")
    plt.show()

# %%
plt.style.use("fivethirtyeight")
@ipywidgets.interact(count=[5000,1000,500,100,1],color=['maroon','green','olive','blue','brown','cyan','dimgrey','salmon','darkseagreen','royalblue','lightgreen'])
def plot_bars(count,color):
    #figure(figsize=(15,7))
    #figure(figsize=(15,7))
    filtered_df_ent = x_ent[x_ent['count'] > count]
    filtered_df_ent.plot(kind='bar', x='countries', y='count',color=color,figsize=[20,10])
    #plt.figure()
    plt.show()
#     plt.bar(x = np.array(x[x['count']>1000].countries), height = np.array(x[x['count']>1000].count), color =color,width = 0.8)
    #plt.show()
# Out:
# interactive(children=(Dropdown(description='count', options=(5000, 1000, 500, 100, 1), value=5000), Dropdown(d…

# %%
with plt.style.context("fivethirtyeight"):
    fig = plt.figure(figsize = (30, 5))
    plt.bar(temp_df_ent['countries'],temp_df_ent['count'], color ='maroon',width = 0.8)
    plt.xlabel("countries entities are located")
    plt.ylabel("Number of offices")
    plt.xticks(rotation=90,fontweight='bold',fontsize=10)
    plt.title("Countries with entites who open offshore accounts")
    plt.show()

# %%
ents[ents['name']=='MOSSACK']
# Out:
# Empty DataFrame
# Columns: [node_id, name, jurisdiction, jurisdiction_description, country_codes, countries, incorporation_date, inactivation_date, struck_off_date, closed_date, ibcRUC, status, company_type, service_provider, sourceID, valid_until, note]
# Index: []

# %%
ent_name =pd.DataFrame(ents['name'].value_counts()).reset_index()
ent_name['index'].to_list()
#ents['name'].value_counts()
# Out:
# ['BRITTEN TRADING LIMITED',
#  'SUNMEAD MANAGEMENT LIMITED',
#  'LATITUD 33 CORP.',
#  'KAMBER LIMITED',
#  'MEMBERS FACTORS LIMITED',
#  'PLEMCO HOLDING INC.',
#  'Sea Trucks Group Limited',
#  'BLUEPOINT ENTERPRISES S.A.',
#  'WORLDWIDE ASSET MANAGEMENT INC.',
#  'LONGFIELD DEVELOPMENTS LIMITED',
#  'ATHOS MANAGEMENT S.A.',
#  'ESTON TRADING LIMITED',
#  'CALICO LIMITED',
#  'SAFFRON INVESTMENTS LIMITED',
#  'STERLING ESTATES LIMITED',
#  'CASA GRANDE DEVELOPMENT, S.A.',
#  'BAYGROVE LIMITED',
#  'LEA BROOK PROPERTY HOLDINGS LTD.',
#  'VALENCIA EQUITIES S.A.',
#  'VALPARAISO S.A.',
#  'SEYMOUR GROUP LTD.',
#  'MOSSFON ASSET MANAGEMENT S.A.',
#  'GOLDKEY HOLDINGS LIMITED',
#  'ALPINO SECURITIES LIMITED',
#  'GREAT OCEAN LIMITED',
#  'ROCKDALE MANAGEMENT LIMITED',
#  'CREEKWOOD ENTERPRISES INC.',
#  'NORM TRADE LTD.',
#  'ALCHEMIE TECHNOLOGY  RDL LIMITED',
#  'PERLINER TRADING CORP.',
#  'ATLAS INVESTMENTS LTD.',
#  'WALBRAY TRADING LTD.',
#  'TERRACE PROPERTIES LIMITED',
# ...

# %%
ents['service_provider'].value_counts()
# Out:
# Mossack Fonseca    213634
# Name: service_provider, dtype: int64

# %% [markdown]
# **Most of the corporate clients were from Hong Kong, Switzerland, the United Kingdom, Luxembourg, Panama, and Cyprus.**

# %%
inter = pd.read_csv("panama_papers.nodes.intermediary.csv", low_memory=False)
inter
# Out:
#         node_id                                       name country_codes  \
# 0      11000001                    MICHAEL PAPAGEORGE, MR.           ZAF
# 1      11000002                         CORFIDUCIA ANSTALT           LIE
# 2      11000003                              DAVID, RONALD           MCO
# 3      11000004                 DE  BOUTSELIS, JEAN-PIERRE           BEL
# 4      11000005                   THE LEVANT LAWYERS (TLL)           LBN
# ...         ...                                        ...           ...
# 14105  11014106                           BRANDON, MICHAEL           CHE
# 14106  11014107                              ROBERT BRINER           CHE
# 14107  11014108                  BROSSARD, LIC. JEAN-MARIE           CHE
# 14108  11014109                       STEVAL MANAGEMENT SA           CHE
# 14109  11014110  MENTHA & ASSOCIES, C/O MR. GERARD BRUNNER           CHE
#
#            countries     status       sourceID  \
# ...

# %%
inter
# Out:
#         node_id                                       name country_codes  \
# 0      11000001                    MICHAEL PAPAGEORGE, MR.           ZAF
# 1      11000002                         CORFIDUCIA ANSTALT           LIE
# 2      11000003                              DAVID, RONALD           MCO
# 3      11000004                 DE  BOUTSELIS, JEAN-PIERRE           BEL
# 4      11000005                   THE LEVANT LAWYERS (TLL)           LBN
# ...         ...                                        ...           ...
# 14105  11014106                           BRANDON, MICHAEL           CHE
# 14106  11014107                              ROBERT BRINER           CHE
# 14107  11014108                  BROSSARD, LIC. JEAN-MARIE           CHE
# 14108  11014109                       STEVAL MANAGEMENT SA           CHE
# 14109  11014110  MENTHA & ASSOCIES, C/O MR. GERARD BRUNNER           CHE
#
#            countries     status       sourceID  \
# ...

# %%
x_inter_name = pd.DataFrame(ents['name'].value_counts()).reset_index()
x_inter_name
# Out:
#                                       index  name
# 0                   BRITTEN TRADING LIMITED     5
# 1                SUNMEAD MANAGEMENT LIMITED     5
# 2                          LATITUD 33 CORP.     5
# 3                            KAMBER LIMITED     5
# 4                   MEMBERS FACTORS LIMITED     4
# ...                                     ...   ...
# 206520  MAN LEE INTERNATIONAL SERVICES LTD.     1
# 206521                  BETRO HOLDING CORP.     1
# 206522                NATVEST FINANCE CORP.     1
# 206523                SHOUP MANAGEMENT INC.     1
# 206524          Kilimanjaro Capital Limited     1
#
# [206525 rows x 2 columns]

# %%
x_inter = pd.DataFrame(ents['countries'].value_counts()).reset_index()
x_inter.columns = ['countries','count']
temp_df_inter = x_inter[x_inter['count']>1000]
temp_df_inter
# Out:
#                  countries  count
# 0                Hong Kong  37911
# 1              Switzerland  37911
# 2                   Panama  15811
# 3                   Jersey  14331
# 4               Luxembourg  10840
# 5           United Kingdom   9619
# 6                 Guernsey   7327
# 7     United Arab Emirates   7269
# 8                  Bahamas   4984
# 9                  Uruguay   4906
# 10             Isle of Man   4892
# 11                  Russia   4197
# 12               Singapore   4081
# 13                  Cyprus   3613
# 14                   China   3213
# 15                  Monaco   3168
# 16           United States   3066
# 17                  Taiwan   2725
# 18           Liechtenstein   2066
# 19               Gibraltar   2039
# 20                Colombia   1854
# 21                 Ecuador   1852
# 22                   Samoa   1613
# 23                  Jordan   1553
# 24                  Brazil   1399
# 25                  Latvia   1380
# ...

# %%
with plt.style.context("fivethirtyeight"):
    fig = plt.figure(figsize = (30, 5))
    plt.bar(temp_df_inter['countries'],temp_df_inter['count'], color ='green',width = 0.8)
    plt.xlabel("countries entities are located")
    plt.ylabel("Number of offices")
    plt.xticks(rotation=90,fontweight='bold',fontsize=10)
    plt.title("Countries with most intermediaries ")
    plt.show()

# %%
x_inter = inter.groupby(['countries','status']).size().reset_index()
x_inter
# Out:
#                countries     status   0
# 0                Andorra     ACTIVE  11
# 1                Andorra  SUSPENDED  10
# 2                 Angola     ACTIVE   1
# 3    Antigua and Barbuda     ACTIVE   1
# 4    Antigua and Barbuda  SUSPENDED   2
# ..                   ...        ...  ..
# 518             Viet Nam  SUSPENDED   3
# 519               Zambia     ACTIVE   1
# 520               Zambia  SUSPENDED   1
# 521             Zimbabwe     ACTIVE   2
# 522             Zimbabwe  SUSPENDED   3
#
# [523 rows x 3 columns]

# %%
temp_df_ent = x_ent[x_ent['count']>1000]
temp_df_ent
# Out:
#                  countries  count
# 0                Hong Kong  37911
# 1              Switzerland  37911
# 2                   Panama  15811
# 3                   Jersey  14331
# 4               Luxembourg  10840
# 5           United Kingdom   9619
# 6                 Guernsey   7327
# 7     United Arab Emirates   7269
# 8                  Bahamas   4984
# 9                  Uruguay   4906
# 10             Isle of Man   4892
# 11                  Russia   4197
# 12               Singapore   4081
# 13                  Cyprus   3613
# 14                   China   3213
# 15                  Monaco   3168
# 16           United States   3066
# 17                  Taiwan   2725
# 18           Liechtenstein   2066
# 19               Gibraltar   2039
# 20                Colombia   1854
# 21                 Ecuador   1852
# 22                   Samoa   1613
# 23                  Jordan   1553
# 24                  Brazil   1399
# 25                  Latvia   1380
# ...

# %%
with plt.style.context("fivethirtyeight"):
    fig = plt.figure(figsize = (30, 5))
    plt.bar(temp_df_ent['countries'],temp_df_ent['count'], color ='green',width = 0.8)
    plt.xlabel("countries entities are located")
    plt.ylabel("Number of offices")
    plt.xticks(rotation=90,fontweight='bold',fontsize=10)
    plt.title("Countries with entites who open offshore accounts")
    plt.show()

# %%
offi = pd.read_csv("panama_papers.nodes.officer.csv", low_memory=False)
#offi["name"] = offi.name.apply(normalise)
offi
# Out:
#          node_id                      name country_codes    countries  \
# 0       12000001                KIM SOO IN           KOR  South Korea
# 1       12000002                 Tian Yuan           CHN        China
# 2       12000003      GREGORY JOHN SOLOMON           AUS    Australia
# 3       12000004            MATSUDA MASUMI           JPN        Japan
# 4       12000005               HO THUY NGA           VNM     Viet Nam
# ...          ...                       ...           ...          ...
# 238397  15006701               Ólöf Nordal           NaN          NaN
# 238398  15006801               James Ibori           NaN          NaN
# 238399  15007201          Arkady Rotenberg           NaN          NaN
# 238400  15007202           Boris Rotenberg           NaN          NaN
# 238401  15007401  Jean-Claude N’Da Ametchi           NaN          NaN
#
#              sourceID                                     valid_until  \
# ...

# %%
offi[offi['name']=='THE BEARER']
# Out:
#          node_id        name country_codes countries       sourceID  \
# 55      12000079  THE BEARER           NaN       NaN  Panama Papers
# 56      12000116  THE BEARER           NaN       NaN  Panama Papers
# 62      12000061  THE BEARER           NaN       NaN  Panama Papers
# 63      12000062  THE BEARER           NaN       NaN  Panama Papers
# 64      12000063  THE BEARER           NaN       NaN  Panama Papers
# ...          ...         ...           ...       ...            ...
# 225236  12002681  THE BEARER           NaN       NaN  Panama Papers
# 225237  12002682  THE BEARER           NaN       NaN  Panama Papers
# 225240  12002685  THE BEARER           NaN       NaN  Panama Papers
# 225241  12002686  THE BEARER           NaN       NaN  Panama Papers
# 225242  12002687  THE BEARER           NaN       NaN  Panama Papers
#
#                                            valid_until note
# 55      The Panama Papers data is current through 2015  NaN
# ...

# %%
offi['name'].value_counts()
# Out:
# THE BEARER                      70871
# EL PORTADOR                      9325
# BEARER                            497
# The Bearer                        434
# Bearer                            156
#                                 ...
# RICARDO ESTRADA LUNA                1
# DVID CAMPBELL                       1
# CHAN SIO PENG                       1
# Miss Hadiah Adel K. Al Dabal        1
# Jean-Claude N’Da Ametchi            1
# Name: name, Length: 122814, dtype: int64

# %%
edges = pd.read_csv("panama_papers.edges.csv", low_memory=False)
edges
# Out:
#         START_ID                TYPE    END_ID                link start_date  \
# 0       10000035  registered_address  14095990  registered address        NaN
# 1       10000044  registered_address  14091035  registered address        NaN
# 2       10000055  registered_address  14095990  registered address        NaN
# 3       10000064  registered_address  14091429  registered address        NaN
# 4       10000089  registered_address  14098253  registered address        NaN
# ...          ...                 ...       ...                 ...        ...
# 674097  15007201          officer_of  10138472            owner of        NaN
# 674098  15007202          officer_of  10143427            owner of        NaN
# 674099  15007202          officer_of  10142797            owner of        NaN
# 674100  15007202          officer_of  10121515            owner of        NaN
# 674101  15007401          officer_of  10021287            owner of        NaN
#
# ...

# %%
#create a directed graph using the networkx package
G = nx.DiGraph()

nodes = [(adds, "address"), (ents, "entities"), (inter, "intermediates"), (offi, "officers")]

#adds nodes based on data stored in several Pandas DataFrames
for df, node_type in nodes:
    #data = df.to_numpy()
    for row in df.itertuples(index=False):
        G.add_node(row.node_id, node_type=node_type, details=row._asdict())
        
#adds edges to the graph based on data stored in edges DataFrames
for row in edges.itertuples(index=False):
    G.add_edge(row.START_ID, row.END_ID, rel_type=row.TYPE, details=row._asdict())

# %%
print(edges.columns)
# Out:
# Index(['START_ID', 'TYPE', 'END_ID', 'link', 'start_date', 'end_date',
#        'sourceID', 'valid_until'],
#       dtype='object')

# %%
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 559600
# 657488

# %%
# subgraphs = [g for g in nx.connected_component_subgraphs(G.to_undirected())]

# %%
nx.__version__
# Out:
# '2.7.1'

# %%
A = [G.subgraph(c) for c in nx.connected_components(G.to_undirected())]

# %%
#A = list(A)[0]

# %%
subgraphs = sorted(A, key=lambda x: x.number_of_nodes(), reverse=True)
print([s.number_of_nodes() for s in A[:10]])
#subgraphs
# Out:
# [455479, 6, 99, 9, 4, 39, 22, 47, 17, 4]

# %%
# A.number_of_nodes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 A.number_of_nodes()
#
# AttributeError: 'list' object has no attribute 'number_of_nodes'

# %%
nx.draw(subgraphs[99])

# %%
nx.draw_networkx(subgraphs[99])

# %%
# plt.figure(figsize=(12,10))

# %%
# pos=nx.kamada_kawai_layout()

# %%
# #node_options dictionary and pass it to nx.draw_networkx_nodes()
# node_options = {"node_color":"black","node_size":30}

# #Draw nodes
# nx.draw_networkx_nodes(G,pos,**node_options)

# %%
# # edge_options dictionary and pass it to nx.draw_networkx_edges()
# edge_options = {"width":0.7,"alpha":0.6,"edge_color":"black"}

# #Draw edges
# nx.draw_networkx_edges(G,pos,**edge_options)

# %%
# set your figure size
plt.figure(figsize=(12,10))

# set your position
pos=nx.kamada_kawai_layout(subgraphs[99])

# set your node_options dictionary and pass it to nx.draw_networkx_nodes()
node_options = {"node_color":"blue","node_size":40}

# set your edge_options dictionary and pass it to nx.draw_networkx_edges()
edge_options = {"width":1,"alpha":0.75,"edge_color":"gray"}

# set your node label  
node_label_options = {"font_size":5,"font_color":"blue","verticalalignment":"bottom","horizontalalignment":"left"}


#Draw nodes
nx.draw_networkx_nodes(subgraphs[99],pos,**node_options)

#Draw edges
nx.draw_networkx_edges(subgraphs[99],pos,**edge_options)

#Draw labels
nx.draw_networkx_labels(subgraphs[99],pos,**node_label_options)

nx.draw_networkx_edge_labels(g, pos, edge_labels)



plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#set your figure size
plt.figure(figsize=(12,10))

#set your position
pos=nx.kamada_kawai_layout(subgraphs[99])

# set your node_options dictionary and pass it to nx.draw_networkx_nodes()
node_options = {"node_color":"orange","node_size":40}

# set your edge_options dictionary and pass it to nx.draw_networkx_edges()
edge_options = {"width":1,"alpha":0.25,"edge_color":"green"}

#Draw nodes
nx.draw_networkx_nodes(subgraphs[99],pos,**node_options)

#Draw edges
nx.draw_networkx_edges(subgraphs[99],pos,**edge_options)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
edges
# Out:
#         START_ID                TYPE    END_ID                link start_date  \
# 0       10000035  registered_address  14095990  registered address        NaN
# 1       10000044  registered_address  14091035  registered address        NaN
# 2       10000055  registered_address  14095990  registered address        NaN
# 3       10000064  registered_address  14091429  registered address        NaN
# 4       10000089  registered_address  14098253  registered address        NaN
# ...          ...                 ...       ...                 ...        ...
# 674097  15007201          officer_of  10138472            owner of        NaN
# 674098  15007202          officer_of  10143427            owner of        NaN
# 674099  15007202          officer_of  10142797            owner of        NaN
# 674100  15007202          officer_of  10121515            owner of        NaN
# 674101  15007401          officer_of  10021287            owner of        NaN
#
# ...

# %%
D = nx.DiGraph()

nodes = [(adds, "address"), (ents, "entities"), (inter, "intermediates"), (offi, "officers")]

#adds nodes based on data stored in several Pandas DataFrames
for df, node_type in nodes:
    #data = df.to_numpy()
    for row in df.itertuples(index=False):
        D.add_node(row.node_id, node_type=node_type, details=row._asdict())

# %%
# https://stackoverflow.com/questions/62963650/how-to-make-networkx-edges-from-pandas-dataframe-rows

D=nx.from_pandas_edgelist(edges,'START_ID','END_ID',edge_attr='TYPE',create_using=nx.DiGraph())

# %%
[e for e in D.edges]
# Out:
# [(10000035, 14095990),
#  (10000044, 14091035),
#  (10000055, 14095990),
#  (10000064, 14091429),
#  (10000089, 14098253),
#  (10000091, 14091429),
#  (10000098, 14099188),
#  (10000105, 14095990),
#  (10000109, 14091429),
#  (10000297, 14095271),
#  (10000464, 14099155),
#  (10000507, 14094124),
#  (10000580, 14097397),
#  (10000581, 14092297),
#  (10000584, 14094414),
#  (10000635, 14095990),
#  (10000644, 14096319),
#  (10000670, 14108530),
#  (10000733, 14092130),
#  (10000765, 14092387),
#  (10000771, 14095991),
#  (10000773, 14106269),
#  (10000774, 14094620),
#  (10000802, 14090945),
#  (10000831, 14098364),
#  (10000847, 14099319),
#  (10000973, 14091921),
#  (10000985, 14097922),
#  (10000986, 14095990),
#  (10001087, 14100320),
#  (10001221, 14099344),
#  (10001315, 14097685),
#  (10001319, 14094124),
#  (10001352, 14096911),
#  (10001483, 14091429),
#  (10001642, 14095991),
#  (10001648, 14095991),
#  (10001657, 14095991),
#  (10001685, 14095991),
#  (10001688, 14095732),
# ...

# %%
# https://stackoverflow.com/questions/62814580/networkx-how-to-add-edge-labels-from-csv-file-in-a-graph    
edge_labels = nx.get_edge_attributes(D, "TYPE")

nx.draw_networkx_edge_labels(D, pos, edge_labels="TYPE")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/networkx/drawing/nx_pylab.py:1134, in draw_networkx_edge_labels(G, pos, edge_labels, label_pos, font_size, font_color, font_family, font_weight, alpha, bbox, horizontalalignment, verticalalignment, ax, rotate, clip_on)
#    1133 try:
# -> 1134     (u, v) = next(iter(labels))  # ensures no edge key provided
#    1135 except ValueError as err:
#
# ValueError: not enough values to unpack (expected 2, got 1)
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Input In [80], in <cell line: 4>()
#       1 # https://stackoverflow.com/questions/62814580/networkx-how-to-add-edge-labels-from-csv-file-in-a-graph
#       2 edge_labels = nx.get_edge_attributes(D, "TYPE")
# ...

# %%
# set your figure size
plt.figure(figsize=(12,10))

# set your position
pos=nx.kamada_kawai_layout(subgraphs[99])

# set your node_options dictionary and pass it to nx.draw_networkx_nodes()
node_options = {"node_color":"blue","node_size":40}

# set your edge_options dictionary and pass it to nx.draw_networkx_edges()
edge_options = {"width":1,"alpha":0.75,"edge_color":"gray"}

# set your node label  
node_label_options = {"font_size":5,"font_color":"blue","verticalalignment":"bottom","horizontalalignment":"left"}


#Draw nodes
nx.draw_networkx_nodes(subgraphs[99],pos,**node_options)

#Draw edges
nx.draw_networkx_edges(subgraphs[99],pos,**edge_options)

#Draw labels
nx.draw_networkx_labels(subgraphs[99],pos,**node_label_options)





plt.show

# %%
# Adding Nodes to Graph 
for index, row in interactome_nodes.iterrows():
    interactome.add_nodes_from(row)

# %% [markdown]
# https://geoffboeing.com/2016/11/osmnx-python-street-networks/
